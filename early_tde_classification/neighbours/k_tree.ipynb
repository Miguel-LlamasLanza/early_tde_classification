# %%
import tde_analysis as td

# %%
data, features = td.get_data('features_all.csv')
# Out:
# /media3/etienne/workdir/TDE/tde_analysis.py:10: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(path)

# %%
types, objids, alertids, is_TDE = td.run_KDE(data, features, n=3)

# %%
td.plot_distributions(data, types)
# Out:
# Neighbours of the TDEs:
# [['Unknown' '16']
#  ['Seyfert_1' '5']
#  ['Early SN Ia candidate' '5']
#  ['Ambiguous' '4']
#  ['SN candidate' '4']
#  ['Microlensing candidate' '3']
#  ['Solar System candidate' '3']
#  ['TDE' '3']
#  ['QSO' '2']
#  ['Blazar' '1']
#  ['LINER' '1']
#  ['AGN' '1']]

# %%
import pandas as pd

pd.DataFrame(objids).to_csv('neighbours.csv')
